# %% [markdown]
# # Simplex algorithm complexity analysis for different input and output variables selection rules.

# %%
from useful import *

# %%
P1 = random_problem(3, 4, 5)
P2 = random_problem(3, 6, 7)
P3 = klee_minty_problem()
P4 = klee_minty_problem(5)

# %%
raport(P1)
# Out:
# Problem jest dany w postaci standardowej:
# LP problem (use typeset mode to see details)
# Zbiór rozwiązań dopuszczalnych jest ograniczony
# Problem ma 22 zbiorów bazowych dopuszczalnych
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/plot/arrow.py:47: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.vertices = np.array(vertices, np.float)
# Graphics object consisting of 103 graphics primitives
# Wejście w cykl jest możliwe
# Lista możliwych cykli: [['q', 'u', 'q'], ['q', 'r', 'q'], ['r', 'v', 'r'], ['u', 'v', 'u'], ['q', 'u', 'v', 'r', 'q'], ['q', 'r', 'v', 'u', 'q']]
#
#  Grafy dla różnych reguł przejścia z zaznaczonymi pivotami na niebiesko:
#
# Reguła Blanda:
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/plot/arrow.py:47: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.vertices = np.array(vertices, np.float)
# Graphics object consisting of 103 graphics primitives
# Graphics object consisting of 44 graphics primitives
# Reguła largest coefficient:
# Graphics object consisting of 103 graphics primitives
# Graphics object consisting of 44 graphics primitives
# Reguła largest increase:
# Graphics object consisting of 103 graphics primitives
# Graphics object consisting of 44 graphics primitives
# Reguła steepest edge:
# Graphics object consisting of 103 graphics primitives
# Graphics object consisting of 44 graphics primitives
# Reguła lowest coefficient:
# Graphics object consisting of 103 graphics primitives
# Graphics object consisting of 44 graphics primitives
#  Tabela przedstawiająca ile dana reguła wykona kroków dla różnych wierzchołków startowych:
#         Bland rule  Largest coefficient rule  Largest increase rule  \
# Vertex
# a                3                         3                      3
# b                2                         2                      2
# c                4                         5                      4
# d                3                         6                      3
# e                4                         4                      4
# f                4                         4                      4
# g                4                         5                      4
# h                4                         5                      5
# i                3                         4                      3
# j                3                         4                      3
# k                2                         2                      2
# l                0                         0                      0
# m                2                         2                      2
# n                2                         2                      2
# o                3                         3                      3
# p                2                         2                      2
# q                3                         3                      3
# r                3                         3                      3
# s                3                         3                      3
# t                3                         3                      3
# u                3                         3                      3
# v                3                         3                      3
#
#         Steepest edge  Own rule
# Vertex
# a                   3         3
# b                   2         6
# c                   4         4
# d                   3         5
# e                   4         4
# f                   4         4
# g                   5         6
# h                   5         5
# i                   4         6
# j                   4         7
# k                   2         2
# l                   0         0
# m                   2         3
# n                   2         2
# o                   3         3
# p                   2         2
# q                   3         4
# r                   3         4
# s                   3         4
# t                   3         3
# u                   3         5
# v                   3         4
# Średnia i maksymalna liczba kroków dla poszczególnych reguł:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Bland rule</th>
#       <th>Largest coefficient rule</th>
#       <th>Largest increase rule</th>
#       <th>Steepest edge</th>
#       <th>Own rule</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>średnia</th>
#       <td>3.00</td>
#       <td>3.38</td>
#       <td>3.05</td>
#       <td>3.19</td>
#       <td>4.10</td>
#     </tr>
#     <tr>
#       <th>maksymalna</th>
#       <td>4</td>
#       <td>6</td>
#       <td>5</td>
#       <td>5</td>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table>

# %%
raport(P2)
# Out:
# Problem jest dany w postaci standardowej:
# LP problem (use typeset mode to see details)
# Zbiór rozwiązań dopuszczalnych jest nieograniczony
# Problem ma 0 zbiorów bazowych dopuszczalnych

# %%
raport(P3)
# Out:
# Problem jest dany w postaci standardowej:
# LP problem (use typeset mode to see details)
# Zbiór rozwiązań dopuszczalnych jest ograniczony
# Problem ma 8 zbiorów bazowych dopuszczalnych
# Graphics object consisting of 21 graphics primitives
# Wejście w cykl jest niemożliwe
#
#  Grafy dla różnych reguł przejścia z zaznaczonymi pivotami na niebiesko:
#
# Reguła Blanda:
# Graphics object consisting of 21 graphics primitives
# Graphics object consisting of 16 graphics primitives
# Reguła largest coefficient:
# Graphics object consisting of 21 graphics primitives
# Graphics object consisting of 16 graphics primitives
# Reguła largest increase:
# Graphics object consisting of 21 graphics primitives
# Graphics object consisting of 16 graphics primitives
# Reguła steepest edge:
# Graphics object consisting of 21 graphics primitives
# Graphics object consisting of 16 graphics primitives
# Reguła lowest coefficient:
# Graphics object consisting of 21 graphics primitives
# Graphics object consisting of 16 graphics primitives
#  Tabela przedstawiająca ile dana reguła wykona kroków dla różnych wierzchołków startowych:
#         Bland rule  Largest coefficient rule  Largest increase rule  \
# Vertex
# a                3                         3                      3
# b                4                         6                      4
# c                2                         2                      2
# d                5                         7                      3
# e                4                         4                      2
# f                5                         5                      3
# g                0                         0                      0
# h                6                         8                      2
#
#         Steepest edge  Own rule
# Vertex
# a                   3         3
# b                   4         4
# c                   2         2
# d                   3         3
# e                   2         2
# f                   3         3
# g                   0         0
# h                   2         2
# Średnia i maksymalna liczba kroków dla poszczególnych reguł:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Bland rule</th>
#       <th>Largest coefficient rule</th>
#       <th>Largest increase rule</th>
#       <th>Steepest edge</th>
#       <th>Own rule</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>średnia</th>
#       <td>4.14</td>
#       <td>5.00</td>
#       <td>2.71</td>
#       <td>2.71</td>
#       <td>2.71</td>
#     </tr>
#     <tr>
#       <th>maksymalna</th>
#       <td>6</td>
#       <td>8</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>

# %%
raport(P4)
# Out:
# Problem jest dany w postaci standardowej:
# LP problem (use typeset mode to see details)
# Zbiór rozwiązań dopuszczalnych jest ograniczony
# Problem ma 32 zbiorów bazowych dopuszczalnych
# Graphics object consisting of 113 graphics primitives
# Wejście w cykl jest niemożliwe
#
#  Grafy dla różnych reguł przejścia z zaznaczonymi pivotami na niebiesko:
#
# Reguła Blanda:
# Graphics object consisting of 113 graphics primitives
# Graphics object consisting of 64 graphics primitives
# Reguła largest coefficient:
# Graphics object consisting of 113 graphics primitives
# Graphics object consisting of 64 graphics primitives
# Reguła largest increase:
# Graphics object consisting of 113 graphics primitives
# Graphics object consisting of 64 graphics primitives
# Reguła steepest edge:
# Graphics object consisting of 113 graphics primitives
# Graphics object consisting of 64 graphics primitives
# Reguła lowest coefficient:
# Graphics object consisting of 113 graphics primitives
# Graphics object consisting of 64 graphics primitives
#  Tabela przedstawiająca ile dana reguła wykona kroków dla różnych wierzchołków startowych:
#         Bland rule  Largest coefficient rule  Largest increase rule  \
# Vertex
# a               11                        11                      5
# b               12                        22                      6
# c                6                         6                      4
# d               13                        27                      5
# e               12                        14                      4
# f               13                        19                      5
# g                3                         3                      3
# h               14                        30                      4
# i               10                        10                      4
# j               13                        23                      5
# k                7                         7                      3
# l               14                        26                      4
# m               13                        15                      3
# n               14                        18                      4
# o                2                         2                      2
# p               15                        31                      3
# q               12                        12                      4
# r               13                        21                      5
# s                5                         5                      3
# t               14                        28                      4
# u               13                        13                      3
# v               14                        20                      4
# w                4                         4                      2
# x               15                        29                      3
# y                9                         9                      3
# z               14                        24                      4
# aa               8                         8                      2
# ab              15                        25                      3
# ac              14                        16                      2
# ad              15                        17                      3
# ae               0                         0                      0
# af              16                        32                      2
#
#         Steepest edge  Own rule
# Vertex
# a                   5         5
# b                   6         6
# c                   4         4
# d                   5         5
# e                   4         4
# f                   5         5
# g                   3         3
# h                   4         4
# i                   4         4
# j                   5         5
# k                   3         3
# l                   4         4
# m                   3         3
# n                   4         4
# o                   2         2
# p                   3         3
# q                   4         4
# r                   5         5
# s                   3         3
# t                   4         4
# u                   3         3
# v                   4         4
# w                   2         2
# x                   5         3
# y                   3         3
# z                   4         4
# aa                  2         2
# ab                  5         3
# ac                  2         2
# ad                  3         3
# ae                  0         0
# af                  2         2
# Średnia i maksymalna liczba kroków dla poszczególnych reguł:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Bland rule</th>
#       <th>Largest coefficient rule</th>
#       <th>Largest increase rule</th>
#       <th>Steepest edge</th>
#       <th>Own rule</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>średnia</th>
#       <td>11.39</td>
#       <td>17.00</td>
#       <td>3.58</td>
#       <td>3.71</td>
#       <td>3.58</td>
#     </tr>
#     <tr>
#       <th>maksymalna</th>
#       <td>16</td>
#       <td>32</td>
#       <td>6</td>
#       <td>6</td>
#       <td>6</td>
#     </tr>
#   </tbody>
# </table>
